# %%
# !pip install --upgrade --quiet langchain-google-genai langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 992.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.4/542.4 kB 6.8 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# Access the API key from Colab Secrets
os.environ["GOOGLE_API_KEY"] = "Place Google API KEY Here"

# %%
# Initialize the model
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# Now you can use the llm to interact with the model
response = llm.invoke("what is KPIT?")
print(response)
# Out:
# content="**KPIT Technologies** (often referred to simply as KPIT) is a leading global technology company specializing in **automotive software and engineering services.**\n\nHere's a breakdown of what they are and what they do:\n\n1.  **Core Business:** KPIT partners with automotive and mobility companies (Original Equipment Manufacturers - OEMs, and Tier 1 suppliers) to help them accelerate their transformation towards clean, smart, and safe future mobility. They do this by developing and integrating software solutions.\n\n2.  **Specialization:** Unlike many broader IT services firms, KPIT has a deep, focused expertise in the automotive domain. Their work primarily revolves around:\n    *   **Autonomous Driving:** Software for self-driving cars, ADAS (Advanced Driver-Assistance Systems).\n    *   **Connected Vehicles:** Solutions for vehicle-to-everything (V2X) communication, infotainment, telematics.\n    *   **Electric Powertrains:** Software for electric vehicle (EV) battery mana
# ...

# %%
response = llm.invoke("Is KPIT a good company for growth who wants to grow in carrier?")
print(response)
# Out:
# content='KPIT Technologies is an interesting company, and whether it\'s "good for growth" really depends on your specific career aspirations and what you mean by "growth."\n\nHere\'s a balanced perspective on KPIT for career growth:\n\n**Strengths for Career Growth at KPIT:**\n\n1.  **Niche Specialization (Automotive & Mobility):** This is KPIT\'s biggest differentiator. If you are passionate about the automotive industry, electric vehicles (EVs), autonomous driving, connected cars, or embedded systems, KPIT offers deep specialization. You\'ll work on cutting-edge technologies that are shaping the future of mobility.\n    *   **Growth Benefit:** You can become a highly specialized expert in a high-demand, high-growth sector. This expertise is valuable and sought after globally.\n\n2.  **Exposure to Leading OEMs and Tier 1 Suppliers:** KPIT works with major global automotive manufacturers and suppliers. This means you\'ll get exposure to international projects, best practices, and pot
# ...
